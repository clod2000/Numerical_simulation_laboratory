# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np




fig = plt.figure(figsize = (16,10) )
fig.suptitle("Equilibration phase", fontsize = (22))


N,temp_ist = np.loadtxt("solido/output_temp.dat", usecols=(0,1), unpack = 'true')

x = np.arange(N[-1])
 
plt.plot(x,temp_ist)
plt.title("temperature")
plt.hlines(0.8 ,0 ,N[-1], color = "red")
